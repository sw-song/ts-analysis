# %%
library("forecast")
library("ggplot2")
# Out:
# Warning message:
# “패키지 ‘forecast’는 R 버전 4.1.2에서 작성되었습니다”
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
#
# Warning message:
# “패키지 ‘ggplot2’는 R 버전 4.1.2에서 작성되었습니다”

# %%
y = arima.sim(n=100, list(ar=0.5))
par(bg='white')
plot.ts(y)
# Out:
# plot without title

# %%
y = arima.sim(n=100, list(ar=0.9), innov=rnorm(100))
par(bg='white')
ggtsdisplay(y)
# Out:
# plot without title

# %%
y = arima.sim(n=100, list(ar=0.5), innov=rnorm(100))
par(bg='white')
ggtsdisplay(y)
# Out:
# plot without title

# %%
y = arima.sim(n=100, list(ar=0.1), innov=rnorm(100))
par(bg='white')
ggtsdisplay(y)
# Out:
# plot without title

# %%
y = arima.sim(n=100, list(ar=-0.1), innov=rnorm(100))
par(bg='white')
ggtsdisplay(y)
# Out:
# plot without title

# %%
y = arima.sim(n=100, list(ar=-0.5), innov=rnorm(100))
par(bg='white')
ggtsdisplay(y)
# Out:
# plot without title

# %%
y = arima.sim(n=100, list(ar=-0.9), innov=rnorm(100))
par(bg='white')
ggtsdisplay(y)
# Out:
# plot without title

# %%
library("random")
# Out:
# Error in library("random"): ‘random’이라고 불리는 패키지가 없습니다
# Traceback:
#
# 1. library("random")

# %%
y = arima.sim(n=100, list(ar=0.5))
par(bg='white')
plot.ts(y)
# Out:
# plot without title

# %%
par(bg='white')
acf(y)
# Out:
# Plot with title “Series  y”
