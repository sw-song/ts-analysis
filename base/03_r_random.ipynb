# %%
library("forecast")
library("ggplot2")
# Out:
# Warning message:
# “패키지 ‘forecast’는 R 버전 4.1.2에서 작성되었습니다”
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
#
# Warning message:
# “패키지 ‘ggplot2’는 R 버전 4.1.2에서 작성되었습니다”

# %%
par(bg='white')
plot.ts(rnorm(500))
# Out:
# plot without title

# %%
set.seed(42)
par(bg='white')
plot(rnorm(500))
# Out:
# plot without title

# %%
set.seed(42)
par(bg='white')
plot(cumsum(rnorm(500)))
# = plot(cumsum(rnorm(500,0,1))
# Out:
# plot without title

# %%
par(bg='white')
plot.ts(cumsum(exp(rnorm(500))))
# Out:
# plot without title

# %%
set.seed(42)
par(bg='white')
plot.ts(cumsum(rnorm(500)))
# Out:
# plot without title

# %%
par(bg='white')
plot.ts(cumsum(rnorm(500)))
# Out:
# plot without title

# %%
par(bg='white')
plot.ts(cumsum(rnorm(1000)))
# Out:
# plot without title

# %%
i = 0
x_vec = cumsum(rnorm(100))
while(i<100){
    x = cumsum(rnorm(500))
    x_vec = cbind(x_vec, x)
    i = i+1
}

# %%
par(bg='white')
ts.plot(x_vec)
# Out:
# plot without title
